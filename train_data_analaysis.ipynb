# %%
import pandas as pd

# %%
import numpy as np

# %%
trains=pd.read_csv("isl_wise_train_detail_03082015_v1.csv")

# %%
# %matplotlib inline

# %%
 import os

# %%
trains.shape
# Out:
# (69006, 12)

# %%
trains.head()
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0   '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1   '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2   '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3   '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4   '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
#
#   source Station Name Destination station Code Destination Station Name
# 0     BHUBANESWAR                         BNC           BANGALORE CANT
# 1     BHUBANESWAR                         BNC           BANGALORE CANT
# ...

# %%
trains.ix[15]
# Out:
# Train No.                           '01081'
# train Name                  DR BSL T F SPL
# islno                                     2
# station Code                           TNA
# Station Name                THANE
# Arrival time                     '22:03:00'
# Departure time                   '22:05:00'
# Distance                                 25
# Source Station Code                    DR
# source Station Name         DADAR
# Destination station Code               BSL
# Destination Station Name    BHUSAVAL JN
# Name: 15, dtype: object

# %%
trains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69006 entries, 0 to 69005
# Data columns (total 12 columns):
# Train No.                   69006 non-null object
# train Name                  69006 non-null object
# islno                       69006 non-null int64
# station Code                69006 non-null object
# Station Name                69006 non-null object
# Arrival time                69006 non-null object
# Departure time              69006 non-null object
# Distance                    69006 non-null int64
# Source Station Code         69006 non-null object
# source Station Name         69006 non-null object
# Destination station Code    69006 non-null object
# Destination Station Name    69006 non-null object
# dtypes: int64(2), object(10)

# %%
trains.loc[3]

# %%
train_no.head()
# Out:
#               Train No.       train Name  islno station Code     Station Name  \
# Train No.
# '00851'   0     '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
#           1     '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
#           2     '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
#           3     '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
#           4     '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# '00852'   7     '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
#           8     '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
#           9     '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
#           10    '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
#           11    '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# '01081'   14    '01081'  DR BSL T F SPL       1         DR    DADAR
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import os

trains=pd.read_csv("isl_wise_train_detail_03082015_v1.csv")
train_no =trains.groupby('Train No.')

# %%
print train_no

# %%
type(train_no.size())
# Out:
# pandas.core.series.Series

# %%
train_no.size()
# Out:
# Train No.
# '00851'       7
# '00852'       7
# '01081'       8
# '01082'       8
# '01149'       4
# '01150'       4
# '01151'       4
# '01152'       4
# '01153'      12
# '01154'      12
# '01156'      25
# '01401'      21
# '01402'      21
# '01419'      19
# '01420'      19
# ...
# '59547'      52
# '59548'      48
# '59801'      11
# '59802'      38
# '59811'      71
# '59812'      66
# '59821'      31
# '59822'      32
# '72451'       3
# '72452'       3
# '74639'       8
# '74640'       8
# '83131'      36
# '83132'      34
# '84369'      39
# Length: 2810, dtype: int64

# %%
size1 = train_no.size()
size1.sort(ascending='False')
size1[::-10].head(10).plot(kind='bar')

# %%
train_name =trains.groupby('Station Name')
train_name.size()
size2 = train_name.size()
size2.sort(ascending='False')
size2[::-10].head(10).plot(kind='bar')

# %%
train_name.size()
# Out:
# Station Name
# A N DEV NAGAR      13
# ABHAIPUR           53
# ABOHAR             17
# ABU ROAD           93
# ACHALDA             5
# ACHHNERA JN        33
# ADAS ROAD           4
# ADAVALI             6
# ADGAON BUZURG       4
# ADHARTAL            4
# ADHIKARI            2
# ADI SAPTAGRAM       1
# ADILABAD           10
# ADINA               2
# ADIPUR             12
# ...
# YENUGONDA            1
# YEOLA               10
# YERPEDU              6
# YERRAGUDIPAD         2
# YERRAGUNTLA         42
# YESVANTPUR JN      143
# YEVAT                8
# YUSUFPUR            20
# ZAFARABAD JN        20
# ZAHIRABAD           16
# ZAMANIA             24
# ZAMPANI HALT         3
# ZANGALAPALLE         6
# ZARAP                2
# ZAWAR                2
# Length: 4337, dtype: int64

# %%
trains['Distance'].mean()
# Out:
# 647.79858273193634

# %%
trains.loc[trains['Distance']>trains['Distance'].mean()]
# Out:
#     Train No.       train Name  islno station Code     Station Name  \
# 3     '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4     '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5     '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6     '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 10    '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11    '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12    '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# 13    '00852'  BNC BBS SUVIDHA      7         BBS   BHUBANESWAR
# 70    '01156'  PVR NAVI KMN SP      1         JM    JALAMB JN
# 72    '01156'  PVR NAVI KMN SP      2         KMN   KHAMGAON
# 88    '01156'  PVR NAVI KMN SP     17         NN    NANDURA
# 89    '01156'  PVR NAVI KMN SP     18         JM    JALAMB JN
# 90    '01156'  PVR NAVI KMN SP     19         SEG   SHEGAON
# 91    '01156'  PVR NAVI KMN SP     20         AK    AKOLA JN
# ...

# %%
trains.loc[trains['Distance']>trains['Distance'].mean()].plot()

# %%
trains.loc[trains['Distance']>trains['Distance'].mean()].max()
# Out:
# Train No.                           '84369'
# train Name                  ZIYARAT EXPRESS
# islno                                   120
# station Code                           ZRDE
# Station Name                ZANGALAPALLE
# Arrival time                     '23:59:00'
# Departure time                   '23:59:00'
# Distance                               4273
# Source Station Code                    YPR
# source Station Name         YESVANTPUR JN
# Destination station Code               YPR
# Destination Station Name    YESVANTPUR JN
# dtype: object
